# %% [markdown]
# ## Scrapping images of cetaceans from Wikipedia page

# %%
import pandas as pd
import requests, os
from tqdm import tqdm
from bs4 import BeautifulSoup, Tag
import json

# %%
species = pd.read_csv("../../data/PhylogeneticTree/species_tree_of_life.csv")
species
# Out:
#           Scientific name                 Common name  \
# 0        Stenella clymene             Clymene dolphin
# 1   Stenella longirostris             Spinner dolphin
# 2     Lagenodelphis hosei            Fraser's dolphin
# 3       Delphinus delphis              Common dolphin
# 4   Stenella coeruleoalba             Striped dolphin
# ..                    ...                         ...
# 70      Caperea marginata           Pygmy right whale
# 71    Eubalaena glacialis  North Atlantic right whale
# 72     Eubalaena japonica   North Pacific right whale
# 73    Eubalaena australis        Southern right whale
# 74     Balaena mysticetus               Bowhead whale
#
#                                    Wikipedia page URL          Genus  \
# 0       https://en.wikipedia.org/wiki/Clymene_dolphin       Stenella
# 1       https://en.wikipedia.org/wiki/Spinner_dolphin       Stenella
# 2    https://en.wikipedia.org/wiki/Fraser%27s_dolphin  Lagenodelphis
# 3        https://en.wikipedia.org/wiki/Common_dolphin      Delphinus
# 4       https://en.wikipedia.org/wiki/Striped_dolphin       Stenella
# ..                                                ...            ...
# 70    https://en.wikipedia.org/wiki/Pygmy_right_whale        Caperea
# 71  https://en.wikipedia.org/wiki/North_Atlantic_r...      Eubalaena
# 72  https://en.wikipedia.org/wiki/North_Pacific_ri...      Eubalaena
# 73  https://en.wikipedia.org/wiki/Southern_right_w...      Eubalaena
# 74        https://en.wikipedia.org/wiki/Bowhead_whale        Balaena
#
#                                  Genus Wikipedia URL         Family  \
# 0             https://en.wikipedia.org/wiki/Stenella    Delphinidae
# 1             https://en.wikipedia.org/wiki/Stenella    Delphinidae
# 2   https://en.wikipedia.org/wiki/Fraser%27s_dolphin    Delphinidae
# 3       https://en.wikipedia.org/wiki/Common_dolphin    Delphinidae
# 4             https://en.wikipedia.org/wiki/Stenella    Delphinidae
# ..                                               ...            ...
# 70   https://en.wikipedia.org/wiki/Pygmy_right_whale  Cetotheriidae
# 71         https://en.wikipedia.org/wiki/Right_whale     Balaenidae
# 72         https://en.wikipedia.org/wiki/Right_whale     Balaenidae
# 73         https://en.wikipedia.org/wiki/Right_whale     Balaenidae
# 74             https://en.wikipedia.org/wiki/Balaena     Balaenidae
#
#                              Family Wikipedia URL      Subfamily  \
# 0   https://en.wikipedia.org/wiki/Oceanic_dolphin    Delphininae
# 1   https://en.wikipedia.org/wiki/Oceanic_dolphin    Delphininae
# 2   https://en.wikipedia.org/wiki/Oceanic_dolphin    Delphininae
# 3   https://en.wikipedia.org/wiki/Oceanic_dolphin    Delphininae
# 4   https://en.wikipedia.org/wiki/Oceanic_dolphin    Delphininae
# ..                                            ...            ...
# 70    https://en.wikipedia.org/wiki/Cetotheriidae  Neobalaenidae
# 71       https://en.wikipedia.org/wiki/Balaenidae            NaN
# 72       https://en.wikipedia.org/wiki/Balaenidae            NaN
# 73       https://en.wikipedia.org/wiki/Balaenidae            NaN
# 74       https://en.wikipedia.org/wiki/Balaenidae            NaN
#
#                               Subfamily Wikipedia URL Superfamily  \
# 0   https://en.wikipedia.org/wiki/Oceanic_dolphin#...         NaN
# 1   https://en.wikipedia.org/wiki/Oceanic_dolphin#...         NaN
# 2   https://en.wikipedia.org/wiki/Oceanic_dolphin#...         NaN
# 3   https://en.wikipedia.org/wiki/Oceanic_dolphin#...         NaN
# 4   https://en.wikipedia.org/wiki/Oceanic_dolphin#...         NaN
# ..                                                ...         ...
# 70        https://en.wikipedia.org/wiki/Neobalaenidae         NaN
# 71                                                NaN         NaN
# 72                                                NaN         NaN
# 73                                                NaN         NaN
# 74                                                NaN         NaN
#
#    Superfamily Wikipedia URL
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 70                       NaN
# 71                       NaN
# 72                       NaN
# 73                       NaN
# 74                       NaN
#
# [75 rows x 11 columns]

# %%
from image_url_scrapper import WikiImageScrapper

# %%
# Set the folder name where images will be stored
my_folder = 'wiki_images'
os.makedirs(my_folder, exist_ok=True)

# Base URL for Wikipedia API
query = 'http://en.wikipedia.org/w/api.php?action=query&prop=pageimages&format=json&piprop=original&titles='

# Wikipedia article to download the main image from
#my_list = philo_common_names#species_list#IDs_and_names["Common name"].dropna().tolist()

# Define User-Agent header to respect Wikipedia's user-client policy :,)
HEADERS = {
    "User-Agent": "WhereWereWhales: cetaceans images from Wikipedia"
}


def get_image_url(page_url):
    """ Gets the main image URL from a Wikipedia article """
    response = None
    try:
        response = requests.get(page_url, headers=HEADERS)
    except Exception as exc:
        print(exc)
        return None
    
    if response is None or response.status_code != 200:
        return None
        
    soup = BeautifulSoup(response.content, "html.parser")
    og_image = soup.find("meta", property="og:image")

    if isinstance(og_image, Tag):
        try:
            return og_image.get("content")
        except Exception as exc:
            print(exc)
            return None
    else:
        print("og:image tag not found")
    return None

    # try:
    #     api_res = requests.get(query + partial_url, headers=HEADERS).json()
    #     first_part = api_res['query']['pages']
    #     for key, value in first_part.items():
    #         if 'original' in value:
    #             return value['original']['source']
    # except Exception as exc:
    #     print(exc)
    #     print("Partial URL: " + partial_url)
    # return None


def download_image(the_url, the_page):
    res = requests.get(the_url, headers=HEADERS) 
    res.raise_for_status()
    
    if res.status_code != 200:
        print(f"Error scraping {the_page}: {res.status_code}")

    # Get the correct file extension
    file_ext = '.' + the_url.split('.')[-1].lower()
    image_file = os.path.join(my_folder, os.path.basename(the_page + file_ext))

    # Save the image
    with open(image_file, 'wb') as f:
        for chunk in res.iter_content(100000):
            f.write(chunk)

    #print(f"Downloaded: {image_file}")

# Download images from Wikipedia articles
image_urls = dict()
for _, (co_name, sc_name, the_url) in tqdm(species[["Common name", "Scientific name", "Wikipedia page URL"]].iterrows(), desc="Scraping Wikipedia images", unit="pages"):
    #the_url = get_image_url(the_page)
    #print(the_page, the_url)
    try:
        #print(f"Downloading an image of a magnificent {the_page}...")
        #download_image(the_url, the_page)
        image_urls[sc_name] = {"common_name":co_name, "image": get_image_url(the_url)}
        
    except:
        print(f"No image found for {co_name} :(")

print("All done!")
# Out:
# Scraping Wikipedia images: 75pages [00:14,  5.18pages/s]
# All done!

# %%
wiki_urls = species[["Scientific name", "Common name", "Wikipedia page URL"]].copy()
scrapper = WikiImageScrapper(wiki_urls)
scrapper.scrap_image_URLs()

image_urls = scrapper.wiki_urls_df[["Scientific name", "Common name", "Image URL"]].copy()

dict_image_urls = {f"{sc_name}":{"common_name": co_name, "image": img_url} for _, (sc_name, co_name, img_url) in image_urls.iterrows()}
# Out:
# Scraping Wikipedia images: 75pages [00:14,  5.11pages/s]
# All done!

# %%
dict_image_urls
# Out:
# {'Stenella clymene': {'common_name': 'Clymene dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/a/aa/Clymenes.jpg'},
#  'Stenella longirostris': {'common_name': 'Spinner dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/64/A_spinner_dolphin_in_the_Red_Sea.jpg/1200px-A_spinner_dolphin_in_the_Red_Sea.jpg'},
#  'Lagenodelphis hosei': {'common_name': "Fraser's dolphin",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Frazer%C2%B4s_dolphin_group.jpg'},
#  'Delphinus delphis': {'common_name': 'Common dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Common_dolphin_noaa.jpg/1200px-Common_dolphin_noaa.jpg'},
#  'Stenella coeruleoalba': {'common_name': 'Striped dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Stenella_coeruleoalba_Ligurian_Sea_02_-_brighter.jpg/1200px-Stenella_coeruleoalba_Ligurian_Sea_02_-_brighter.jpg'},
#  'Stenella attenuata': {'common_name': 'Pantropical spotted dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Pantropical_spotted_dolphin_swimming_off_the_coast_of_Costa_Rica.jpg/1200px-Pantropical_spotted_dolphin_swimming_off_the_coast_of_Costa_Rica.jpg'},
#  'Stenella frontalis': {'common_name': 'Atlantic spotted dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Atlantic_spotted_dolphin_%28Stenella_frontalis%29_NOAA.jpg/1200px-Atlantic_spotted_dolphin_%28Stenella_frontalis%29_NOAA.jpg'},
#  'Tursiops truncatus': {'common_name': 'Common bottlenose dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Tursiops_truncatus_01-cropped.jpg/1200px-Tursiops_truncatus_01-cropped.jpg'},
#  'Tursiops aduncus': {'common_name': 'Indo-Pacific bottlenose dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/8/87/Tursiops_aduncus%2C_Port_River%2C_Adelaide%2C_Australia_-_2003.jpg'},
#  'Sousa chinensis': {'common_name': 'Indo-Pacific humpback dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Pink_Dolphin.JPG/1200px-Pink_Dolphin.JPG'},
#  'Sotalia guianensis': {'common_name': 'Guiana dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/a/a6/Descri%C3%A7%C3%A3o_in%C3%ADcio_ou_comportamento.jpg'},
#  'Globicephala macrorhynchus': {'common_name': 'Short-finned pilot whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Globicephala_macrorhynchus_Kurzflossen-Grindwal_DSCF8148.JPG/1200px-Globicephala_macrorhynchus_Kurzflossen-Grindwal_DSCF8148.JPG'},
#  'Globicephala melas': {'common_name': 'Long-finned pilot whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/85/Pilot_Whale_-_Flickr_-_gailhampshire.jpg/1200px-Pilot_Whale_-_Flickr_-_gailhampshire.jpg'},
#  'Feresa attenuata': {'common_name': 'Pygmy killer whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Pygmy_killer_whales_%28Feresa_attenuata%29_off_of_Guam_%28anim252384854%29.jpg/1200px-Pygmy_killer_whales_%28Feresa_attenuata%29_off_of_Guam_%28anim252384854%29.jpg'},
#  'Peponocephala electra': {'common_name': 'Melon-headed whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Peponocephala_electra_Mayotte.jpg/1200px-Peponocephala_electra_Mayotte.jpg'},
#  'Pseudorca crassidens': {'common_name': 'False killer whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Pseudoorca_Crassidens_-_False_Killer_Whale.jpg/1200px-Pseudoorca_Crassidens_-_False_Killer_Whale.jpg'},
#  'Grampus griseus': {'common_name': "Risso's dolphin",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/9/93/Grampo.jpg'},
#  'Steno bredanensis': {'common_name': 'Rough-toothed dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/2/26/Rough_toothed_dolphin.jpg'},
#  'Orcaella brevirostris': {'common_name': 'Irrawaddy dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/a/ae/Irrawaddy_dolphin-Orcaella_brevirostris_by_2eight.jpg'},
#  'Orcaella heinsohni': {'common_name': 'Australian snubfin dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/3/3f/Snubfin-3.jpg'},
#  'Cephalorhynchus heavisidii': {'common_name': "Heaviside's dolphin",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Dolphins_at_L%C3%BCderitz%2C_Namibia_%283144863196%29.jpg/1200px-Dolphins_at_L%C3%BCderitz%2C_Namibia_%283144863196%29.jpg'},
#  'Sagmatias australis': {'common_name': "Peale's dolphin",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Peale%27s_dolphin_%28Sagmatias_australis%29_off_the_coast_of_Calbuco%2C_Chile_%28380921709%29.jpg/1200px-Peale%27s_dolphin_%28Sagmatias_australis%29_off_the_coast_of_Calbuco%2C_Chile_%28380921709%29.jpg'},
#  'Cephalorhynchus commersonii': {'common_name': "Commerson's dolphin",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/a/a1/Tonina1_%282731842634%29.jpg'},
#  'Sagmatias obscurus': {'common_name': 'Dusky dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/1/13/DuskyDolphin.jpg'},
#  'Sagmatias obliquidens': {'common_name': 'Pacific white-sided dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Pacific_white-sided_dolphins_%28Lagenorhynchus_obliquidens%29_NOAA.jpg'},
#  'Lissodelphis borealis': {'common_name': 'Northern right whale dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Anim1749_-_Flickr_-_NOAA_Photo_Library.jpg/1200px-Anim1749_-_Flickr_-_NOAA_Photo_Library.jpg'},
#  'Lissodelphis peronii': {'common_name': 'Southern right whale dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Lissodelphis_peronii_1847.jpg/1200px-Lissodelphis_peronii_1847.jpg'},
#  'Lagenorhynchus albirostris': {'common_name': 'White beaked dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/7/72/Witsnuitdolfijn_-_Lagenorhynchus_albirostris.jpg'},
#  'Orcinus orca': {'common_name': 'Orca',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Killerwhales_jumping.jpg/1200px-Killerwhales_jumping.jpg'},
#  'Leucopleurus acutus': {'common_name': 'Atlantic white-sided dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Atlantic_white-sided_dolphin.jpg'},
#  'Phocoena dioptrica': {'common_name': 'Spectacled porpoise',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Spectacled_porpoise_size.svg/1200px-Spectacled_porpoise_size.svg.png'},
#  'Phocoena spinipinnis': {'common_name': "Burmeister's porpoise",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Burmeister%27s_porpoise_size.svg/1200px-Burmeister%27s_porpoise_size.svg.png'},
#  'Phocoena phocoena': {'common_name': 'Harbour porpoise',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Ecomare_-_bruinvis_Michael_in_2015_%28bruinvis-michael2015-9313-sw%29.jpg/1200px-Ecomare_-_bruinvis_Michael_in_2015_%28bruinvis-michael2015-9313-sw%29.jpg'},
#  'Phocoenoides dalli': {'common_name': "Dall's porpoise",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Phocoenoides_dalli_%28Dall%27s_porpoise%29.jpg/1200px-Phocoenoides_dalli_%28Dall%27s_porpoise%29.jpg'},
#  'Neophocaena phocaenoides': {'common_name': 'Indo-Pacific finless porpoise',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/c/c6/Stamps_of_Indonesia%2C_040-05.jpg'},
#  'Delphinapterus leucas': {'common_name': 'Beluga whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Oceanogr%C3%A0fic_29102004.jpg/1200px-Oceanogr%C3%A0fic_29102004.jpg'},
#  'Monodon monoceros': {'common_name': 'Narwhal',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/1200px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg'},
#  'Pontoporia blainvillei': {'common_name': 'La Plata dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Pontoporia_blainvillei_296896096.jpg/1200px-Pontoporia_blainvillei_296896096.jpg'},
#  'Inia geoffrensis': {'common_name': 'Amazon river dolphin',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Amazonas-Flussdelfin_Orinoko3.jpg/1200px-Amazonas-Flussdelfin_Orinoko3.jpg'},
#  'Lipotes vexillifer': {'common_name': 'Baiji',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/d/dd/Baiji_1.jpg'},
#  'Mesoplodon perrini': {'common_name': "Perrin's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Mesoplodon_perrini.jpg/1200px-Mesoplodon_perrini.jpg'},
#  'Mesoplodon peruvianus': {'common_name': 'Pygmy beaked whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/Hector%27s_beaked_whale_size.svg/1200px-Hector%27s_beaked_whale_size.svg.png'},
#  'Mesoplodon densirostris': {'common_name': "Blaincille's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/Blainville%27s_beaked_whale_size.svg/1200px-Blainville%27s_beaked_whale_size.svg.png'},
#  'Mesoplodon stejnegeri': {'common_name': "Stejneger's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/Mesoplodon_stejnegeri.jpg/1200px-Mesoplodon_stejnegeri.jpg'},
#  'Mesoplodon grayi': {'common_name': "Gray's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/64/Gray%27s_beaked_whale_size.svg/1200px-Gray%27s_beaked_whale_size.svg.png'},
#  'Mesoplodon hectori': {'common_name': "Hector's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/Hector%27s_beaked_whale_size.svg/1200px-Hector%27s_beaked_whale_size.svg.png'},
#  'Mesoplodon bowdoini': {'common_name': "Andrews' beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Mesoplodon_bowdoini.jpg/1200px-Mesoplodon_bowdoini.jpg'},
#  'Mesoplodon carlhubbsi': {'common_name': "Hubbs' beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Mesoplodon_carlhubbsi.jpg/1200px-Mesoplodon_carlhubbsi.jpg'},
#  'Mesoplodon layardii': {'common_name': 'Strap-toothed whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Mesoplodon_layardii.jpg/1200px-Mesoplodon_layardii.jpg'},
#  'Mesoplodon mirus': {'common_name': "True's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/The_True%27s_beaked_whale_photographed_underwater.jpg/1200px-The_True%27s_beaked_whale_photographed_underwater.jpg'},
#  'Mesoplodon europaeus': {'common_name': "Gervais's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Mesoplodon_europaeus_2.jpg/1200px-Mesoplodon_europaeus_2.jpg'},
#  'Mesoplodon ginkgodens': {'common_name': 'Ginkgo-toothed beaked whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a8/Mesoplodon_ginkgodens_2.jpg/1200px-Mesoplodon_ginkgodens_2.jpg'},
#  'Mesoplodon bidens': {'common_name': "Sowerby's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Mesoplodon_bidens_2.jpg/1200px-Mesoplodon_bidens_2.jpg'},
#  'Hyperoodon planifrons': {'common_name': 'Southern bottlenose whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Hyperoodon_planifrons.jpg/1200px-Hyperoodon_planifrons.jpg'},
#  'Hyperoodon ampullatus': {'common_name': 'Northern bottlenose whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Hyperoodon_ampullatus_2.jpg/1200px-Hyperoodon_ampullatus_2.jpg'},
#  'Ziphius cavirostris': {'common_name': "Cuvier's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Ziphius_carvirostris.jpg/1200px-Ziphius_carvirostris.jpg'},
#  'Tasmacetus shepherdi': {'common_name': "Shepherd's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Tasmacetus_shepherdi.jpg/1200px-Tasmacetus_shepherdi.jpg'},
#  'Berardius arnuxii': {'common_name': "Arnoux's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Berardius_arnuxii_2.jpg/1200px-Berardius_arnuxii_2.jpg'},
#  'Berardius bairdii': {'common_name': "Baird's beaked whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Cetacea_range_map_Baird_27s_Beaked_Whale.png/1200px-Cetacea_range_map_Baird_27s_Beaked_Whale.png'},
#  'Kogia sima': {'common_name': 'Dwarf sperm whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/5/58/Dwarf_sperm_whale_%28NOAA_Pitman%29.jpg'},
#  'Kogia breviceps': {'common_name': 'Pygmy sperm whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Pygmy_sperm_whale.jpg/1200px-Pygmy_sperm_whale.jpg'},
#  'Physeter macrocephalus': {'common_name': 'Sperm whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Mother_and_baby_sperm_whale.jpg/1200px-Mother_and_baby_sperm_whale.jpg'},
#  'Balaenoptera edeni': {'common_name': "Bryde's whale",
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/3/35/Balaenoptera_brydei.jpg'},
#  'Balaenoptera borealis': {'common_name': 'Sei whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Sei_whale_mother_and_calf_Christin_Khan_NOAA.jpg/1200px-Sei_whale_mother_and_calf_Christin_Khan_NOAA.jpg'},
#  'Balaenoptera musculus': {'common_name': 'Blue whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Anim1754_-_Flickr_-_NOAA_Photo_Library.jpg/1200px-Anim1754_-_Flickr_-_NOAA_Photo_Library.jpg'},
#  'Balaenoptera physalus': {'common_name': 'Fin whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Finhval_%281%29.jpg/1200px-Finhval_%281%29.jpg'},
#  'Megaptera novaeangliae': {'common_name': 'Humpback whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/6/61/Humpback_Whale_underwater_shot.jpg'},
#  'Eschrichtius robustus': {'common_name': 'Gray whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/00/Ballena_gris_adulta_con_su_ballenato.jpg/1200px-Ballena_gris_adulta_con_su_ballenato.jpg'},
#  'Balaenoptera bonaerensis': {'common_name': 'Antartic minke whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Minke_whale_in_ross_sea.jpg/1200px-Minke_whale_in_ross_sea.jpg'},
#  'Balaenoptera acutorostrata': {'common_name': 'Common minke whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/f/f4/Dwarf_minke_whale_%2830694501214%29.jpg'},
#  'Caperea marginata': {'common_name': 'Pygmy right whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/b/bb/Pygmy_right_whale.png'},
#  'Eubalaena glacialis': {'common_name': 'North Atlantic right whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/GRNMS_-_Right_Whales_%2831361234602%29.jpg/1200px-GRNMS_-_Right_Whales_%2831361234602%29.jpg'},
#  'Eubalaena japonica': {'common_name': 'North Pacific right whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/3/37/Eubalaena_japonica_drawing.jpg'},
#  'Eubalaena australis': {'common_name': 'Southern right whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Southern_right_whale6.jpg'},
#  'Balaena mysticetus': {'common_name': 'Bowhead whale',
#   'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Bowhead_Whale_NOAA.jpg/1200px-Bowhead_Whale_NOAA.jpg'}}

# %% [markdown]
# We manually inspected all the images and discovered that some of the retrieved images either did not correspond to the true main page of the Wikipedia article (mainly because our method for fetching the images is not robust enough) or they would depict the animal suffering or dying which could represent sensitive content to the user of our website. We manually explore the Creative Commons database to replace those images with more appropriate ones.

# %%
dict_image_urls["Phocoena dioptrica"] = {"common_name":'Spectacled porpoise', "image": "https://upload.wikimedia.org/wikipedia/commons/c/c4/Subadult_female_spectacled_porpoise.png"}
dict_image_urls["Phocoena spinipinnis"] = {"common_name":"Burmeister's porpoise", "image":"https://upload.wikimedia.org/wikipedia/commons/1/1c/Burmeister%27s_porpoise_-_Phocoena_spinipinnis_-_2022-02-24.png"}
dict_image_urls["Lipotes vexillifer"] = {"common_name":'Baiji', "image":"https://upload.wikimedia.org/wikipedia/commons/5/5e/Lipotes_vexillifer.png"}
dict_image_urls["Mesoplodon peruvianus"] = {"common_name":'Pygmy beaked whale', "image": "https://upload.wikimedia.org/wikipedia/commons/9/93/Mesoplodon_peruvianus.jpg"}
dict_image_urls["Mesoplodon densirostris"] = {"common_name":"Blaincille's beaked whale", "image": "https://upload.wikimedia.org/wikipedia/commons/b/b9/Mesoplodon_densirostris.jpg"}
dict_image_urls["Mesoplodon grayi"] = {"common_name":"Gray's beaked whale", "image": "https://upload.wikimedia.org/wikipedia/commons/6/6a/Mesoplodon_grayi_2.jpg"}
dict_image_urls["Mesoplodon hectori"] = {"common_name":"Hector's beaked whale", "image": "https://upload.wikimedia.org/wikipedia/commons/b/b5/Mesoplodon_hectori.jpg"}
dict_image_urls["Berardius bairdii"] = {"common_name":"Baird's beaked whale", "image": "https://upload.wikimedia.org/wikipedia/commons/e/e2/Berardius_bairdii_2.jpg"}
dict_image_urls['Kogia breviceps'] = {"common_name":'Pygmy sperm whale', "image": "https://upload.wikimedia.org/wikipedia/commons/b/b6/FMIB_50832_Pygmy_Sperm_Whale.jpeg"}

# %%
len(dict_image_urls), species.shape[0]
# Out:
# (75, 75)

# %%
tree_json_file = open("../../data/PhylogeneticTree/hierarchical_tree.json")
hier_tree_dict = json.load(tree_json_file)
hier_tree_dict
# Out:
# {'scientific_name': 'CETACEAN',
#  'common_name': None,
#  'image': None,
#  'parent_branch_name': None,
#  'children': [{'scientific_name': 1,
#    'common_name': None,
#    'image': None,
#    'parent_branch_name': 'Odontoceti',
#    'children': [{'scientific_name': 2,
#      'common_name': None,
#      'image': None,
#      'parent_branch_name': None,
#      'children': [{'scientific_name': 4,
#        'common_name': None,
#        'image': None,
#        'parent_branch_name': 'Kogiidae',
#        'family': 'Kogiidae',
#        'children': [{'scientific_name': 'Kogia sima',
#          'common_name': 'Dwarf sperm whale',
#          'image': 'https://upload.wikimedia.org/wikipedia/commons/5/58/Dwarf_sperm_whale_%28NOAA_Pitman%29.jpg',
#          'parent_branch_name': None,
#          'children': [],
#          'family': 'Kogiidae',
#          'genus': 'Kogia'},
#         {'scientific_name': 'Kogia breviceps',
#          'common_name': 'Pygmy sperm whale',
#          'image': 'https://upload.wikimedia.org/wikipedia/commons/b/b6/FMIB_50832_Pygmy_Sperm_Whale.jpeg',
#          'parent_branch_name': None,
#          'children': [],
#          'family': 'Kogiidae',
#          'genus': 'Kogia'}]},
#       {'scientific_name': 'Physeter macrocephalus',
#        'common_name': 'Sperm whale',
#        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Mother_and_baby_sperm_whale.jpg/1200px-Mother_and_baby_sperm_whale.jpg',
#        'parent_branch_name': 'Physeteroidea',
#        'children': [],
#        'family': 'Physeteridae',
#        'genus': 'Physeter'}]},
#     {'scientific_name': 3,
#      'common_name': None,
#      'image': None,
#      'parent_branch_name': None,
#      'children': [{'scientific_name': 5,
#        'common_name': None,
#        'image': None,
#        'parent_branch_name': None,
#        'family': 'Ziphiidae',
#        'children': [{'scientific_name': 7,
#          'common_name': None,
#          'image': None,
#          'parent_branch_name': None,
#          'family': 'Ziphiidae',
#          'children': [{'scientific_name': 9,
#            'common_name': None,
#            'image': None,
#            'parent_branch_name': None,
#            'family': 'Ziphiidae',
#            'children': [{'scientific_name': 'Ziphius cavirostris',
#              'common_name': "Cuvier's beaked whale",
#              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Ziphius_carvirostris.jpg/1200px-Ziphius_carvirostris.jpg',
#              'parent_branch_name': 'Ziphiinae',
#              'children': [],
#              'family': 'Ziphiidae',
#              'genus': 'Ziphius'},
#             {'scientific_name': 10,
#              'common_name': None,
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Ziphiidae',
#              'children': [{'scientific_name': 11,
#                'common_name': None,
#                'image': None,
#                'parent_branch_name': 'Hyperoodon',
#                'family': 'Ziphiidae',
#                'children': [{'scientific_name': 'Hyperoodon planifrons',
#                  'common_name': 'Southern bottlenose whale',
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Hyperoodon_planifrons.jpg/1200px-Hyperoodon_planifrons.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Ziphiidae',
#                  'genus': 'Hyperoodon'},
#                 {'scientific_name': 'Hyperoodon ampullatus',
#                  'common_name': 'Northern bottlenose whale',
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Hyperoodon_ampullatus_2.jpg/1200px-Hyperoodon_ampullatus_2.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Ziphiidae',
#                  'genus': 'Hyperoodon'}]},
#               {'scientific_name': 12,
#                'common_name': None,
#                'image': None,
#                'parent_branch_name': 'Mesoplodon',
#                'family': 'Ziphiidae',
#                'children': [{'scientific_name': 13,
#                  'common_name': None,
#                  'image': None,
#                  'parent_branch_name': None,
#                  'family': 'Ziphiidae',
#                  'children': [{'scientific_name': 15,
#                    'common_name': None,
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Ziphiidae',
#                    'children': [{'scientific_name': 16,
#                      'common_name': None,
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Ziphiidae',
#                      'children': [{'scientific_name': 'Mesoplodon mirus',
#                        'common_name': "True's beaked whale",
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/The_True%27s_beaked_whale_photographed_underwater.jpg/1200px-The_True%27s_beaked_whale_photographed_underwater.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Ziphiidae',
#                        'genus': 'Mesoplodon'},
#                       {'scientific_name': 'Mesoplodon europaeus',
#                        'common_name': "Gervais's beaked whale",
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Mesoplodon_europaeus_2.jpg/1200px-Mesoplodon_europaeus_2.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Ziphiidae',
#                        'genus': 'Mesoplodon'}]},
#                     {'scientific_name': 'Mesoplodon ginkgodens',
#                      'common_name': 'Ginkgo-toothed beaked whale',
#                      'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a8/Mesoplodon_ginkgodens_2.jpg/1200px-Mesoplodon_ginkgodens_2.jpg',
#                      'parent_branch_name': None,
#                      'children': [],
#                      'family': 'Ziphiidae',
#                      'genus': 'Mesoplodon'}]},
#                   {'scientific_name': 'Mesoplodon bidens',
#                    'common_name': "Sowerby's beaked whale",
#                    'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Mesoplodon_bidens_2.jpg/1200px-Mesoplodon_bidens_2.jpg',
#                    'parent_branch_name': None,
#                    'children': [],
#                    'family': 'Ziphiidae',
#                    'genus': 'Mesoplodon'}]},
#                 {'scientific_name': 14,
#                  'common_name': None,
#                  'image': None,
#                  'parent_branch_name': None,
#                  'family': 'Ziphiidae',
#                  'children': [{'scientific_name': 17,
#                    'common_name': None,
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Ziphiidae',
#                    'children': [{'scientific_name': 'Mesoplodon layardii',
#                      'common_name': 'Strap-toothed whale',
#                      'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Mesoplodon_layardii.jpg/1200px-Mesoplodon_layardii.jpg',
#                      'parent_branch_name': None,
#                      'children': [],
#                      'family': 'Ziphiidae',
#                      'genus': 'Mesoplodon'},
#                     {'scientific_name': 19,
#                      'common_name': None,
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Ziphiidae',
#                      'children': [{'scientific_name': 'Mesoplodon carlhubbsi',
#                        'common_name': "Hubbs' beaked whale",
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Mesoplodon_carlhubbsi.jpg/1200px-Mesoplodon_carlhubbsi.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Ziphiidae',
#                        'genus': 'Mesoplodon'},
#                       {'scientific_name': 'Mesoplodon bowdoini',
#                        'common_name': "Andrews' beaked whale",
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Mesoplodon_bowdoini.jpg/1200px-Mesoplodon_bowdoini.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Ziphiidae',
#                        'genus': 'Mesoplodon'}]}]},
#                   {'scientific_name': 18,
#                    'common_name': None,
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Ziphiidae',
#                    'children': [{'scientific_name': 'Mesoplodon hectori',
#                      'common_name': "Hector's beaked whale",
#                      'image': 'https://upload.wikimedia.org/wikipedia/commons/b/b5/Mesoplodon_hectori.jpg',
#                      'parent_branch_name': None,
#                      'children': [],
#                      'family': 'Ziphiidae',
#                      'genus': 'Mesoplodon'},
#                     {'scientific_name': 20,
#                      'common_name': None,
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Ziphiidae',
#                      'children': [{'scientific_name': 'Mesoplodon grayi',
#                        'common_name': "Gray's beaked whale",
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/6/6a/Mesoplodon_grayi_2.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Ziphiidae',
#                        'genus': 'Mesoplodon'},
#                       {'scientific_name': 21,
#                        'common_name': None,
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Ziphiidae',
#                        'children': [{'scientific_name': 'Mesoplodon stejnegeri',
#                          'common_name': "Stejneger's beaked whale",
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/Mesoplodon_stejnegeri.jpg/1200px-Mesoplodon_stejnegeri.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Ziphiidae',
#                          'genus': 'Mesoplodon'},
#                         {'scientific_name': 22,
#                          'common_name': None,
#                          'image': None,
#                          'parent_branch_name': None,
#                          'family': 'Ziphiidae',
#                          'children': [{'scientific_name': 'Mesoplodon densirostris',
#                            'common_name': "Blaincille's beaked whale",
#                            'image': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Mesoplodon_densirostris.jpg',
#                            'parent_branch_name': None,
#                            'children': [],
#                            'family': 'Ziphiidae',
#                            'genus': 'Mesoplodon'},
#                           {'scientific_name': 23,
#                            'common_name': None,
#                            'image': None,
#                            'parent_branch_name': None,
#                            'family': 'Ziphiidae',
#                            'children': [{'scientific_name': 'Mesoplodon perrini',
#                              'common_name': "Perrin's beaked whale",
#                              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Mesoplodon_perrini.jpg/1200px-Mesoplodon_perrini.jpg',
#                              'parent_branch_name': None,
#                              'children': [],
#                              'family': 'Ziphiidae',
#                              'genus': 'Mesoplodon'},
#                             {'scientific_name': 'Mesoplodon peruvianus',
#                              'common_name': 'Pygmy beaked whale',
#                              'image': 'https://upload.wikimedia.org/wikipedia/commons/9/93/Mesoplodon_peruvianus.jpg',
#                              'parent_branch_name': None,
#                              'children': [],
#                              'family': 'Ziphiidae',
#                              'genus': 'Mesoplodon'}]}]}]}]}]}]}]}]}]},
#           {'scientific_name': 'Tasmacetus shepherdi',
#            'common_name': "Shepherd's beaked whale",
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Tasmacetus_shepherdi.jpg/1200px-Tasmacetus_shepherdi.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Ziphiidae',
#            'genus': 'Tasmacetus'}]},
#         {'scientific_name': 8,
#          'common_name': None,
#          'image': None,
#          'parent_branch_name': None,
#          'family': 'Ziphiidae',
#          'children': [{'scientific_name': 'Berardius bairdii',
#            'common_name': "Baird's beaked whale",
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/e/e2/Berardius_bairdii_2.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Ziphiidae',
#            'genus': 'Berardius'},
#           {'scientific_name': 'Berardius arnuxii',
#            'common_name': "Arnoux's beaked whale",
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Berardius_arnuxii_2.jpg/1200px-Berardius_arnuxii_2.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Ziphiidae',
#            'genus': 'Berardius'}]}]},
#       {'scientific_name': 6,
#        'common_name': None,
#        'image': None,
#        'parent_branch_name': None,
#        'children': [{'scientific_name': 24,
#          'common_name': None,
#          'image': None,
#          'parent_branch_name': None,
#          'children': [{'scientific_name': 27,
#            'common_name': None,
#            'image': None,
#            'parent_branch_name': None,
#            'children': [{'scientific_name': 29,
#              'common_name': None,
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Monodontidae',
#              'children': [{'scientific_name': 'Delphinapterus leucas',
#                'common_name': 'Beluga whale',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Oceanogr%C3%A0fic_29102004.jpg/1200px-Oceanogr%C3%A0fic_29102004.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Monodontidae',
#                'genus': 'Delphinarepterus'},
#               {'scientific_name': 'Monodon monoceros',
#                'common_name': 'Narwhal',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg/1200px-%D0%9D%D0%B0%D1%80%D0%B2%D0%B0%D0%BB_%D0%B2_%D1%80%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9_%D0%90%D1%80%D0%BA%D1%82%D0%B8%D0%BA%D0%B5.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Monodontidae',
#                'genus': 'Monodon'}]},
#             {'scientific_name': 30,
#              'common_name': '',
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Phocoenidae',
#              'children': [{'scientific_name': 31,
#                'common_name': '',
#                'image': None,
#                'parent_branch_name': None,
#                'family': 'Phocoenidae',
#                'children': [{'scientific_name': 32,
#                  'common_name': '',
#                  'image': None,
#                  'parent_branch_name': None,
#                  'family': 'Phocoenidae',
#                  'children': [{'scientific_name': 'Phocoena phocoena',
#                    'common_name': 'Harbour porpoise',
#                    'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Ecomare_-_bruinvis_Michael_in_2015_%28bruinvis-michael2015-9313-sw%29.jpg/1200px-Ecomare_-_bruinvis_Michael_in_2015_%28bruinvis-michael2015-9313-sw%29.jpg',
#                    'parent_branch_name': None,
#                    'children': [],
#                    'family': 'Phocoenidae',
#                    'genus': 'Phocoena'},
#                   {'scientific_name': 33,
#                    'common_name': '',
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Phocoenidae',
#                    'children': [{'scientific_name': 'Phocoena dioptrica',
#                      'common_name': 'Spectacled porpoise',
#                      'image': 'https://upload.wikimedia.org/wikipedia/commons/c/c4/Subadult_female_spectacled_porpoise.png',
#                      'parent_branch_name': None,
#                      'children': [],
#                      'family': 'Phocoenidae',
#                      'genus': 'Phocoena'},
#                     {'scientific_name': 'Phocoena spinipinnis',
#                      'common_name': "Burmeister's porpoise",
#                      'image': 'https://upload.wikimedia.org/wikipedia/commons/1/1c/Burmeister%27s_porpoise_-_Phocoena_spinipinnis_-_2022-02-24.png',
#                      'parent_branch_name': None,
#                      'children': [],
#                      'family': 'Phocoenidae',
#                      'genus': 'Phocoena'}]}]},
#                 {'scientific_name': 'Phocoenoides dalli',
#                  'common_name': "Dall's porpoise",
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Phocoenoides_dalli_%28Dall%27s_porpoise%29.jpg/1200px-Phocoenoides_dalli_%28Dall%27s_porpoise%29.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Phocoenidae',
#                  'genus': 'Phocoanoides'}]},
#               {'scientific_name': 'Neophocaena phocaenoides',
#                'common_name': 'Indo-Pacific finless porpoise',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/c/c6/Stamps_of_Indonesia%2C_040-05.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Phocoenidae',
#                'genus': 'Neophocaena'}]}]},
#           {'scientific_name': 28,
#            'common_name': '',
#            'image': None,
#            'parent_branch_name': None,
#            'family': 'Delphinidae',
#            'children': [{'scientific_name': 'Leucopleurus acutus',
#              'common_name': 'Atlantic white-sided dolphin',
#              'image': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Atlantic_white-sided_dolphin.jpg',
#              'parent_branch_name': None,
#              'children': [],
#              'family': 'Delphinidae',
#              'genus': 'Lagenorhynchus'},
#             {'scientific_name': 34,
#              'common_name': '',
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Delphinidae',
#              'children': [{'scientific_name': 'Orcinus orca',
#                'common_name': 'Orca',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Killerwhales_jumping.jpg/1200px-Killerwhales_jumping.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Delphinidae',
#                'genus': 'Orcinus'},
#               {'scientific_name': 35,
#                'common_name': '',
#                'image': None,
#                'parent_branch_name': None,
#                'family': 'Delphinidae',
#                'children': [{'scientific_name': 'Lagenorhynchus albirostris',
#                  'common_name': 'White beaked dolphin',
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/7/72/Witsnuitdolfijn_-_Lagenorhynchus_albirostris.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Delphinidae',
#                  'genus': 'Lagenorhynchus'},
#                 {'scientific_name': 36,
#                  'common_name': '',
#                  'image': None,
#                  'parent_branch_name': None,
#                  'family': 'Delphinidae',
#                  'children': [{'scientific_name': 37,
#                    'common_name': '',
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Delphinidae',
#                    'children': [{'scientific_name': 39,
#                      'common_name': '',
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Delphinidae',
#                      'children': [{'scientific_name': 41,
#                        'common_name': '',
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Delphinidae',
#                        'children': [{'scientific_name': 'Cephalorhynchus commersonii',
#                          'common_name': "Commerson's dolphin",
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/a/a1/Tonina1_%282731842634%29.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Cephalorhynchus'},
#                         {'scientific_name': 43,
#                          'common_name': '',
#                          'image': None,
#                          'parent_branch_name': None,
#                          'family': 'Delphinidae',
#                          'children': [{'scientific_name': 'Cephalorhynchus heavisidii',
#                            'common_name': "Heaviside's dolphin",
#                            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Dolphins_at_L%C3%BCderitz%2C_Namibia_%283144863196%29.jpg/1200px-Dolphins_at_L%C3%BCderitz%2C_Namibia_%283144863196%29.jpg',
#                            'parent_branch_name': None,
#                            'children': [],
#                            'family': 'Delphinidae',
#                            'genus': 'Cephalorhynchus'},
#                           {'scientific_name': 'Sagmatias australis',
#                            'common_name': "Peale's dolphin",
#                            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Peale%27s_dolphin_%28Sagmatias_australis%29_off_the_coast_of_Calbuco%2C_Chile_%28380921709%29.jpg/1200px-Peale%27s_dolphin_%28Sagmatias_australis%29_off_the_coast_of_Calbuco%2C_Chile_%28380921709%29.jpg',
#                            'parent_branch_name': None,
#                            'children': [],
#                            'family': 'Delphinidae',
#                            'genus': 'Lagenorhynchus'}]}]},
#                       {'scientific_name': 42,
#                        'common_name': '',
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Delphinidae',
#                        'children': [{'scientific_name': 'Sagmatias obliquidens',
#                          'common_name': 'Pacific white-sided dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Pacific_white-sided_dolphins_%28Lagenorhynchus_obliquidens%29_NOAA.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Lagenorhynchus'},
#                         {'scientific_name': 'Sagmatias obscurus',
#                          'common_name': 'Dusky dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/1/13/DuskyDolphin.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Lagenorhynchus'}]}]},
#                     {'scientific_name': 40,
#                      'common_name': '',
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Delphinidae',
#                      'children': [{'scientific_name': 'Lissodelphis peronii',
#                        'common_name': 'Southern right whale dolphin',
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Lissodelphis_peronii_1847.jpg/1200px-Lissodelphis_peronii_1847.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Delphinidae',
#                        'genus': 'Lissodelphis'},
#                       {'scientific_name': 'Lissodelphis borealis',
#                        'common_name': 'Norhtern right whale dolphin',
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Anim1749_-_Flickr_-_NOAA_Photo_Library.jpg/1200px-Anim1749_-_Flickr_-_NOAA_Photo_Library.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Delphinidae',
#                        'genus': 'Lissodelphis'}]}]},
#                   {'scientific_name': 38,
#                    'common_name': '',
#                    'image': None,
#                    'parent_branch_name': None,
#                    'family': 'Delphinidae',
#                    'children': [{'scientific_name': 44,
#                      'common_name': '',
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Delphinidae',
#                      'children': [{'scientific_name': 46,
#                        'common_name': '',
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Delphinidae',
#                        'children': [{'scientific_name': 'Steno bredanensis',
#                          'common_name': 'Rough-toothed dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/2/26/Rough_toothed_dolphin.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Steno'},
#                         {'scientific_name': 48,
#                          'common_name': '',
#                          'image': None,
#                          'parent_branch_name': None,
#                          'family': 'Delphinidae',
#                          'children': [{'scientific_name': 'Grampus griseus',
#                            'common_name': "Risso's dolphin",
#                            'image': 'https://upload.wikimedia.org/wikipedia/commons/9/93/Grampo.jpg',
#                            'parent_branch_name': None,
#                            'children': [],
#                            'family': 'Delphinidae',
#                            'genus': 'Grampus'},
#                           {'scientific_name': 49,
#                            'common_name': '',
#                            'image': None,
#                            'parent_branch_name': None,
#                            'family': 'Delphinidae',
#                            'children': [{'scientific_name': 50,
#                              'common_name': '',
#                              'image': None,
#                              'parent_branch_name': None,
#                              'family': 'Delphinidae',
#                              'children': [{'scientific_name': 51,
#                                'common_name': '',
#                                'image': None,
#                                'parent_branch_name': None,
#                                'family': 'Delphinidae',
#                                'children': [{'scientific_name': 'Globicephala melas',
#                                  'common_name': 'Long-finned pilot whale',
#                                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/85/Pilot_Whale_-_Flickr_-_gailhampshire.jpg/1200px-Pilot_Whale_-_Flickr_-_gailhampshire.jpg',
#                                  'parent_branch_name': None,
#                                  'children': [],
#                                  'family': 'Delphinidae',
#                                  'genus': 'Globicephalinae'},
#                                 {'scientific_name': 'Globicephala macrorhynchus',
#                                  'common_name': 'Short-finned pilot whale',
#                                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Globicephala_macrorhynchus_Kurzflossen-Grindwal_DSCF8148.JPG/1200px-Globicephala_macrorhynchus_Kurzflossen-Grindwal_DSCF8148.JPG',
#                                  'parent_branch_name': None,
#                                  'children': [],
#                                  'family': 'Delphinidae',
#                                  'genus': 'Globicephalinae'}]},
#                               {'scientific_name': 52,
#                                'common_name': '',
#                                'image': None,
#                                'parent_branch_name': None,
#                                'family': 'Delphinidae',
#                                'children': [{'scientific_name': 'Feresa attenuata',
#                                  'common_name': 'Pygmy killer whale',
#                                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Pygmy_killer_whales_%28Feresa_attenuata%29_off_of_Guam_%28anim252384854%29.jpg/1200px-Pygmy_killer_whales_%28Feresa_attenuata%29_off_of_Guam_%28anim252384854%29.jpg',
#                                  'parent_branch_name': None,
#                                  'children': [],
#                                  'family': 'Delphinidae',
#                                  'genus': 'Feresa'},
#                                 {'scientific_name': 'Peponocephala electra',
#                                  'common_name': 'Melon-headed whale',
#                                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Peponocephala_electra_Mayotte.jpg/1200px-Peponocephala_electra_Mayotte.jpg',
#                                  'parent_branch_name': None,
#                                  'children': [],
#                                  'family': 'Delphinidae',
#                                  'genus': 'Peponocephala'}]}]},
#                             {'scientific_name': 'Pseudorca crassidens',
#                              'common_name': 'False killer whale',
#                              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Pseudoorca_Crassidens_-_False_Killer_Whale.jpg/1200px-Pseudoorca_Crassidens_-_False_Killer_Whale.jpg',
#                              'parent_branch_name': None,
#                              'children': [],
#                              'family': 'Delphinidae',
#                              'genus': 'Pseudorca'}]}]}]},
#                       {'scientific_name': 47,
#                        'common_name': '',
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Delphinidae',
#                        'children': [{'scientific_name': 'Orcaella brevirostris',
#                          'common_name': 'Irrawaddy dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/a/ae/Irrawaddy_dolphin-Orcaella_brevirostris_by_2eight.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Orcaella'},
#                         {'scientific_name': 'Orcaella heinsohni',
#                          'common_name': 'Australian snubfin dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/3/3f/Snubfin-3.jpg',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Orcaella'}]}]},
#                     {'scientific_name': 45,
#                      'common_name': '',
#                      'image': None,
#                      'parent_branch_name': None,
#                      'family': 'Delphinidae',
#                      'children': [{'scientific_name': 'Sotalia guianensis',
#                        'common_name': 'Guiana dolphin',
#                        'image': 'https://upload.wikimedia.org/wikipedia/commons/a/a6/Descri%C3%A7%C3%A3o_in%C3%ADcio_ou_comportamento.jpg',
#                        'parent_branch_name': None,
#                        'children': [],
#                        'family': 'Delphinidae',
#                        'genus': 'Sotalia'},
#                       {'scientific_name': 53,
#                        'common_name': '',
#                        'image': None,
#                        'parent_branch_name': None,
#                        'family': 'Delphinidae',
#                        'children': [{'scientific_name': 'Sousa chinensis',
#                          'common_name': 'Indo-Pacific humpback dolphin',
#                          'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Pink_Dolphin.JPG/1200px-Pink_Dolphin.JPG',
#                          'parent_branch_name': None,
#                          'children': [],
#                          'family': 'Delphinidae',
#                          'genus': 'Sousa'},
#                         {'scientific_name': 54,
#                          'common_name': '',
#                          'image': None,
#                          'parent_branch_name': None,
#                          'family': 'Delphinidae',
#                          'children': [{'scientific_name': 55,
#                            'common_name': '',
#                            'image': None,
#                            'parent_branch_name': None,
#                            'family': 'Delphinidae',
#                            'children': [{'scientific_name': 57,
#                              'common_name': '',
#                              'image': None,
#                              'parent_branch_name': None,
#                              'family': 'Delphinidae',
#                              'children': [{'scientific_name': 'Tursiops truncatus',
#                                'common_name': 'Common bottlenose dolphin',
#                                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Tursiops_truncatus_01-cropped.jpg/1200px-Tursiops_truncatus_01-cropped.jpg',
#                                'parent_branch_name': None,
#                                'children': [],
#                                'family': 'Delphinidae',
#                                'genus': 'Tursiops'},
#                               {'scientific_name': 'Tursiops aduncus',
#                                'common_name': 'Indo-Pacific bottlenose dolphin',
#                                'image': 'https://upload.wikimedia.org/wikipedia/commons/8/87/Tursiops_aduncus%2C_Port_River%2C_Adelaide%2C_Australia_-_2003.jpg',
#                                'parent_branch_name': None,
#                                'children': [],
#                                'family': 'Delphinidae',
#                                'genus': 'Tursiops'}]},
#                             {'scientific_name': 58,
#                              'common_name': '',
#                              'image': None,
#                              'parent_branch_name': None,
#                              'family': 'Delphinidae',
#                              'children': [{'scientific_name': 'Stenella frontalis',
#                                'common_name': 'Atlantic spotted dolphin',
#                                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Atlantic_spotted_dolphin_%28Stenella_frontalis%29_NOAA.jpg/1200px-Atlantic_spotted_dolphin_%28Stenella_frontalis%29_NOAA.jpg',
#                                'parent_branch_name': None,
#                                'children': [],
#                                'family': 'Delphinidae',
#                                'genus': 'Stenella'},
#                               {'scientific_name': 'Stenella attenuata',
#                                'common_name': 'Pantropical spotted dolphin',
#                                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Pantropical_spotted_dolphin_swimming_off_the_coast_of_Costa_Rica.jpg/1200px-Pantropical_spotted_dolphin_swimming_off_the_coast_of_Costa_Rica.jpg',
#                                'parent_branch_name': None,
#                                'children': [],
#                                'family': 'Delphinidae',
#                                'genus': 'Stenella'}]}]},
#                           {'scientific_name': 56,
#                            'common_name': '',
#                            'image': None,
#                            'parent_branch_name': None,
#                            'family': 'Delphinidae',
#                            'children': [{'scientific_name': 'Stenella coeruleoalba',
#                              'common_name': 'Striped dolphin',
#                              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Stenella_coeruleoalba_Ligurian_Sea_02_-_brighter.jpg/1200px-Stenella_coeruleoalba_Ligurian_Sea_02_-_brighter.jpg',
#                              'parent_branch_name': None,
#                              'children': [],
#                              'family': 'Delphinidae',
#                              'genus': 'Stenella'},
#                             {'scientific_name': 59,
#                              'common_name': '',
#                              'image': None,
#                              'parent_branch_name': None,
#                              'family': 'Delphinidae',
#                              'children': [{'scientific_name': 'Delphinus delphis',
#                                'common_name': 'Common dolphin',
#                                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Common_dolphin_noaa.jpg/1200px-Common_dolphin_noaa.jpg',
#                                'parent_branch_name': None,
#                                'children': [],
#                                'family': 'Delphinidae',
#                                'genus': 'Delphinus'},
#                               {'scientific_name': 60,
#                                'common_name': '',
#                                'image': None,
#                                'parent_branch_name': None,
#                                'family': 'Delphinidae',
#                                'children': [{'scientific_name': 'Lagenodelphis hosei',
#                                  'common_name': "Fraser's dolphin",
#                                  'image': 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Frazer%C2%B4s_dolphin_group.jpg',
#                                  'parent_branch_name': None,
#                                  'children': [],
#                                  'family': 'Delphinidae',
#                                  'genus': 'Lagenodelphis'},
#                                 {'scientific_name': 61,
#                                  'common_name': '',
#                                  'image': None,
#                                  'parent_branch_name': None,
#                                  'family': 'Delphinidae',
#                                  'children': [{'scientific_name': 'Stenella longirostris',
#                                    'common_name': 'Spinner dolphin',
#                                    'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/64/A_spinner_dolphin_in_the_Red_Sea.jpg/1200px-A_spinner_dolphin_in_the_Red_Sea.jpg',
#                                    'parent_branch_name': None,
#                                    'children': [],
#                                    'family': 'Delphinidae',
#                                    'genus': 'Stenella'},
#                                   {'scientific_name': 'Stenella clymene',
#                                    'common_name': 'Clymene dolphin',
#                                    'image': 'https://upload.wikimedia.org/wikipedia/commons/a/aa/Clymenes.jpg',
#                                    'parent_branch_name': None,
#                                    'children': [],
#                                    'family': 'Delphinidae',
#                                    'genus': 'Stenella'}]}]}]}]}]}]}]}]}]}]}]}]}]},
#         {'scientific_name': 25,
#          'common_name': '',
#          'image': None,
#          'parent_branch_name': None,
#          'children': [{'scientific_name': 26,
#            'common_name': '',
#            'image': None,
#            'parent_branch_name': None,
#            'children': [{'scientific_name': 'Pontoporia blainvillei',
#              'common_name': 'La Plata dolphin',
#              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Pontoporia_blainvillei_296896096.jpg/1200px-Pontoporia_blainvillei_296896096.jpg',
#              'parent_branch_name': None,
#              'children': [],
#              'family': 'Pontoporiidae',
#              'genus': 'Pontoporia'},
#             {'scientific_name': 'Inia geoffrensis',
#              'common_name': 'Amazon river dolphin',
#              'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Amazonas-Flussdelfin_Orinoko3.jpg/1200px-Amazonas-Flussdelfin_Orinoko3.jpg',
#              'parent_branch_name': None,
#              'children': [],
#              'family': 'Iniidae',
#              'genus': 'Inia'}]},
#           {'scientific_name': 'Lipotes vexillifer',
#            'common_name': 'Baiji',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/5/5e/Lipotes_vexillifer.png',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Lipotidae',
#            'genus': 'Lipotes'}]}]}]}]},
#   {'scientific_name': 62,
#    'common_name': '',
#    'image': None,
#    'parent_branch_name': 'Mysticeti',
#    'children': [{'scientific_name': 64,
#      'common_name': '',
#      'image': None,
#      'parent_branch_name': 'Balaenidae',
#      'family': 'Balaenidae',
#      'children': [{'scientific_name': 'Balaena mysticetus',
#        'common_name': 'Bowhead whale',
#        'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Bowhead_Whale_NOAA.jpg/1200px-Bowhead_Whale_NOAA.jpg',
#        'parent_branch_name': 'Balaena',
#        'children': [],
#        'family': 'Balaenidae',
#        'genus': 'Balaena'},
#       {'scientific_name': 66,
#        'common_name': '',
#        'image': None,
#        'parent_branch_name': 'Eubalaenea',
#        'family': 'Balaenidae',
#        'children': [{'scientific_name': 67,
#          'common_name': '',
#          'image': None,
#          'family': 'Balaenidae',
#          'children': [{'scientific_name': 'Eubalaena glacialis',
#            'common_name': 'North Atlantic right whale',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/GRNMS_-_Right_Whales_%2831361234602%29.jpg/1200px-GRNMS_-_Right_Whales_%2831361234602%29.jpg',
#            'children': [],
#            'family': 'Balaenidae',
#            'genus': 'Eubalaena'},
#           {'scientific_name': 'Eubalaena japonica',
#            'common_name': 'North Pacific right whale',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/3/37/Eubalaena_japonica_drawing.jpg',
#            'children': [],
#            'family': 'Balaenidae',
#            'genus': 'Eubalaena'}]},
#         {'scientific_name': 'Eubalaena australis',
#          'common_name': 'Southern right whale',
#          'image': 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Southern_right_whale6.jpg',
#          'children': [],
#          'family': 'Balaenidae',
#          'genus': 'Eubalaena'}]}]},
#     {'scientific_name': 63,
#      'common_name': '',
#      'image': None,
#      'parent_branch_name': None,
#      'children': [{'scientific_name': 'Caperea marginata',
#        'common_name': 'Pygmy right whale',
#        'image': 'https://upload.wikimedia.org/wikipedia/commons/b/bb/Pygmy_right_whale.png',
#        'parent_branch_name': None,
#        'children': [],
#        'family': 'Cetotheriidae',
#        'genus': 'Caperea'},
#       {'scientific_name': 65,
#        'common_name': '',
#        'image': None,
#        'parent_branch_name': None,
#        'children': [{'scientific_name': 69,
#          'common_name': '',
#          'image': None,
#          'parent_branch_name': None,
#          'family': 'Balaenopteridae',
#          'children': [{'scientific_name': 'Balaenoptera bonaerensis',
#            'common_name': 'Antartic minke whale',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Minke_whale_in_ross_sea.jpg/1200px-Minke_whale_in_ross_sea.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Balaenopteridae',
#            'genus': 'Balaenoptera'},
#           {'scientific_name': 'Balaenoptera acutorostrata',
#            'common_name': 'Common minke whale',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/f/f4/Dwarf_minke_whale_%2830694501214%29.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Balaenopteridae',
#            'genus': 'Balaenoptera'}]},
#         {'scientific_name': 68,
#          'common_name': '',
#          'image': None,
#          'parent_branch_name': None,
#          'children': [{'scientific_name': 'Eschrichtius robustus',
#            'common_name': 'Gray whale',
#            'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/00/Ballena_gris_adulta_con_su_ballenato.jpg/1200px-Ballena_gris_adulta_con_su_ballenato.jpg',
#            'parent_branch_name': None,
#            'children': [],
#            'family': 'Eschrichtiidae',
#            'genus': 'Eschrichtius'},
#           {'scientific_name': 70,
#            'common_name': '',
#            'image': None,
#            'parent_branch_name': None,
#            'family': 'Balaenopteridae',
#            'children': [{'scientific_name': 71,
#              'common_name': '',
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Balaenopteridae',
#              'children': [{'scientific_name': 'Megaptera novaeangliae',
#                'common_name': 'Humpback whale',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/6/61/Humpback_Whale_underwater_shot.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Balaenopteridae',
#                'genus': 'Balaenoptera'},
#               {'scientific_name': 'Balaenoptera physalus',
#                'common_name': 'Fin whale',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Finhval_%281%29.jpg/1200px-Finhval_%281%29.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Balaenopteridae',
#                'genus': 'Balaenoptera'}]},
#             {'scientific_name': 72,
#              'common_name': '',
#              'image': None,
#              'parent_branch_name': None,
#              'family': 'Balaenopteridae',
#              'children': [{'scientific_name': 'Balaenoptera musculus',
#                'common_name': 'Blue whale',
#                'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Anim1754_-_Flickr_-_NOAA_Photo_Library.jpg/1200px-Anim1754_-_Flickr_-_NOAA_Photo_Library.jpg',
#                'parent_branch_name': None,
#                'children': [],
#                'family': 'Balaenopteridae',
#                'genus': 'Balaenoptera'},
#               {'scientific_name': 73,
#                'common_name': '',
#                'image': None,
#                'parent_branch_name': None,
#                'family': 'Balaenopteridae',
#                'children': [{'scientific_name': 'Balaenoptera borealis',
#                  'common_name': 'Sei whale',
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Sei_whale_mother_and_calf_Christin_Khan_NOAA.jpg/1200px-Sei_whale_mother_and_calf_Christin_Khan_NOAA.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Balaenopteridae',
#                  'genus': 'Balaenoptera'},
#                 {'scientific_name': 'Balaenoptera edeni',
#                  'common_name': "Bryde's whale",
#                  'image': 'https://upload.wikimedia.org/wikipedia/commons/3/35/Balaenoptera_brydei.jpg',
#                  'parent_branch_name': None,
#                  'children': [],
#                  'family': 'Balaenopteridae',
#                  'genus': 'Balaenoptera'}]}]}]}]}]}]}]}]}

# %%
species_df = species.set_index("Scientific name", drop=False)
species_df.loc["Tursiops truncatus"].Family
# Out:
# 'Delphinidae'

# %%
def sets_common_name_and_image_url(node):
    children_list = node["children"]
    if len(children_list) == 0:
        sc_name = node["scientific_name"]
        node["common_name"] = dict_image_urls[sc_name]["common_name"]
        node["image"] = dict_image_urls[sc_name]["image"]
        node["genus"] = species_df.loc[sc_name]["Genus"]
        node["family"] = species_df.loc[sc_name]["Family"]
    else:
        for child in children_list:
            sets_common_name_and_image_url(child)

# %%
sets_common_name_and_image_url(hier_tree_dict)

# %%
#write test_tree into a json file
if True:
    with open("../../data/PhylogeneticTree/hierarchical_tree.json", "w") as f: 
        json.dump(hier_tree_dict, f, indent=4)
